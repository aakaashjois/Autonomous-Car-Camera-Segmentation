# %%
import torch
from torch import nn
from torchvision import models
from torchsummary import summary

class FCN(nn.Module):

    def __init__(self, n_class):
        super().__init__()
        
        self.base_model = models.resnet18(pretrained=True)
        
        layers = list(self.base_model.children())
        self.layer1 = nn.Sequential(*layers[:5]) # size=(N, 64, x.H/2, x.W/2)
        self.upsample1 = nn.Upsample(scale_factor=4, mode='bilinear', align_corners=False)
        self.layer2 = layers[5]  # size=(N, 128, x.H/4, x.W/4)
        self.upsample2 = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=False)
        self.layer3 = layers[6]  # size=(N, 256, x.H/8, x.W/8)
        self.upsample3 = nn.Upsample(scale_factor=16, mode='bilinear', align_corners=False)
        self.layer4 = layers[7]  # size=(N, 512, x.H/16, x.W/16)
        self.upsample4 = nn.Upsample(scale_factor=32, mode='bilinear', align_corners=False)
        
        self.conv = nn.Conv2d(64 + 128 + 256 + 512, n_class, 1)
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self, x):
        x = self.layer1(x)
        up1 = self.upsample1(x)
        x = self.layer2(x)
        up2 = self.upsample2(x)
        x = self.layer3(x)
        up3 = self.upsample3(x)
        x = self.layer4(x)
        up4 = self.upsample4(x)
        
        merge = torch.cat([up1, up2, up3, up4], dim=1)
        merge = self.conv(merge)
        out = self.softmax(merge)
        
        return out

fcn_model = FCN(13)

# %%
summary(fcn_model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#             Conv2d-2         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-3         [-1, 64, 112, 112]             128
#        BatchNorm2d-4         [-1, 64, 112, 112]             128
#               ReLU-5         [-1, 64, 112, 112]               0
#               ReLU-6         [-1, 64, 112, 112]               0
#          MaxPool2d-7           [-1, 64, 56, 56]               0
#          MaxPool2d-8           [-1, 64, 56, 56]               0
#             Conv2d-9           [-1, 64, 56, 56]          36,864
#            Conv2d-10           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-11           [-1, 64, 56, 56]             128
#       BatchNorm2d-12           [-1, 64, 56, 56]             128
#              ReLU-13           [-1, 64, 56, 56]               0
#              ReLU-14           [-1, 64, 56, 56]               0
#            Conv2d-15           [-1, 64, 56, 56]          36,864
#            Conv2d-16           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-17           [-1, 64, 56, 56]             128
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#              ReLU-20           [-1, 64, 56, 56]               0
#        BasicBlock-21           [-1, 64, 56, 56]               0
#        BasicBlock-22           [-1, 64, 56, 56]               0
#            Conv2d-23           [-1, 64, 56, 56]          36,864
#            Conv2d-24           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-25           [-1, 64, 56, 56]             128
#       BatchNorm2d-26           [-1, 64, 56, 56]             128
#              ReLU-27           [-1, 64, 56, 56]               0
#              ReLU-28           [-1, 64, 56, 56]               0
#            Conv2d-29           [-1, 64, 56, 56]          36,864
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#       BatchNorm2d-32           [-1, 64, 56, 56]             128
#              ReLU-33           [-1, 64, 56, 56]               0
#              ReLU-34           [-1, 64, 56, 56]               0
#        BasicBlock-35           [-1, 64, 56, 56]               0
#        BasicBlock-36           [-1, 64, 56, 56]               0
#          Upsample-37         [-1, 64, 224, 224]               0
#            Conv2d-38          [-1, 128, 28, 28]          73,728
#            Conv2d-39          [-1, 128, 28, 28]          73,728
#       BatchNorm2d-40          [-1, 128, 28, 28]             256
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#              ReLU-43          [-1, 128, 28, 28]               0
#            Conv2d-44          [-1, 128, 28, 28]         147,456
#            Conv2d-45          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-46          [-1, 128, 28, 28]             256
#       BatchNorm2d-47          [-1, 128, 28, 28]             256
#            Conv2d-48          [-1, 128, 28, 28]           8,192
#            Conv2d-49          [-1, 128, 28, 28]           8,192
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#       BatchNorm2d-51          [-1, 128, 28, 28]             256
#              ReLU-52          [-1, 128, 28, 28]               0
#              ReLU-53          [-1, 128, 28, 28]               0
#        BasicBlock-54          [-1, 128, 28, 28]               0
#        BasicBlock-55          [-1, 128, 28, 28]               0
#            Conv2d-56          [-1, 128, 28, 28]         147,456
#            Conv2d-57          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-58          [-1, 128, 28, 28]             256
#       BatchNorm2d-59          [-1, 128, 28, 28]             256
#              ReLU-60          [-1, 128, 28, 28]               0
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#            Conv2d-63          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-64          [-1, 128, 28, 28]             256
#       BatchNorm2d-65          [-1, 128, 28, 28]             256
#              ReLU-66          [-1, 128, 28, 28]               0
#              ReLU-67          [-1, 128, 28, 28]               0
#        BasicBlock-68          [-1, 128, 28, 28]               0
#        BasicBlock-69          [-1, 128, 28, 28]               0
#          Upsample-70        [-1, 128, 224, 224]               0
#            Conv2d-71          [-1, 256, 14, 14]         294,912
#            Conv2d-72          [-1, 256, 14, 14]         294,912
#       BatchNorm2d-73          [-1, 256, 14, 14]             512
#       BatchNorm2d-74          [-1, 256, 14, 14]             512
#              ReLU-75          [-1, 256, 14, 14]               0
#              ReLU-76          [-1, 256, 14, 14]               0
#            Conv2d-77          [-1, 256, 14, 14]         589,824
#            Conv2d-78          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-79          [-1, 256, 14, 14]             512
#       BatchNorm2d-80          [-1, 256, 14, 14]             512
#            Conv2d-81          [-1, 256, 14, 14]          32,768
#            Conv2d-82          [-1, 256, 14, 14]          32,768
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#       BatchNorm2d-84          [-1, 256, 14, 14]             512
#              ReLU-85          [-1, 256, 14, 14]               0
#              ReLU-86          [-1, 256, 14, 14]               0
#        BasicBlock-87          [-1, 256, 14, 14]               0
#        BasicBlock-88          [-1, 256, 14, 14]               0
#            Conv2d-89          [-1, 256, 14, 14]         589,824
#            Conv2d-90          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-91          [-1, 256, 14, 14]             512
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#              ReLU-94          [-1, 256, 14, 14]               0
#            Conv2d-95          [-1, 256, 14, 14]         589,824
#            Conv2d-96          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-97          [-1, 256, 14, 14]             512
#       BatchNorm2d-98          [-1, 256, 14, 14]             512
#              ReLU-99          [-1, 256, 14, 14]               0
#             ReLU-100          [-1, 256, 14, 14]               0
#       BasicBlock-101          [-1, 256, 14, 14]               0
#       BasicBlock-102          [-1, 256, 14, 14]               0
#         Upsample-103        [-1, 256, 224, 224]               0
#           Conv2d-104            [-1, 512, 7, 7]       1,179,648
#           Conv2d-105            [-1, 512, 7, 7]       1,179,648
#      BatchNorm2d-106            [-1, 512, 7, 7]           1,024
#      BatchNorm2d-107            [-1, 512, 7, 7]           1,024
#             ReLU-108            [-1, 512, 7, 7]               0
#             ReLU-109            [-1, 512, 7, 7]               0
#           Conv2d-110            [-1, 512, 7, 7]       2,359,296
#           Conv2d-111            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-112            [-1, 512, 7, 7]           1,024
#      BatchNorm2d-113            [-1, 512, 7, 7]           1,024
#           Conv2d-114            [-1, 512, 7, 7]         131,072
#           Conv2d-115            [-1, 512, 7, 7]         131,072
#      BatchNorm2d-116            [-1, 512, 7, 7]           1,024
#      BatchNorm2d-117            [-1, 512, 7, 7]           1,024
#             ReLU-118            [-1, 512, 7, 7]               0
#             ReLU-119            [-1, 512, 7, 7]               0
#       BasicBlock-120            [-1, 512, 7, 7]               0
#       BasicBlock-121            [-1, 512, 7, 7]               0
#           Conv2d-122            [-1, 512, 7, 7]       2,359,296
#           Conv2d-123            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-124            [-1, 512, 7, 7]           1,024
#      BatchNorm2d-125            [-1, 512, 7, 7]           1,024
#             ReLU-126            [-1, 512, 7, 7]               0
#             ReLU-127            [-1, 512, 7, 7]               0
#           Conv2d-128            [-1, 512, 7, 7]       2,359,296
#           Conv2d-129            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-130            [-1, 512, 7, 7]           1,024
#      BatchNorm2d-131            [-1, 512, 7, 7]           1,024
#             ReLU-132            [-1, 512, 7, 7]               0
#             ReLU-133            [-1, 512, 7, 7]               0
#       BasicBlock-134            [-1, 512, 7, 7]               0
#       BasicBlock-135            [-1, 512, 7, 7]               0
#         Upsample-136        [-1, 512, 224, 224]               0
#           Conv2d-137         [-1, 13, 224, 224]          12,493
#          Softmax-138         [-1, 13, 224, 224]               0
# ================================================================
# Total params: 22,365,517
# Trainable params: 22,365,517
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 503.02
# Params size (MB): 85.32
# Estimated Total Size (MB): 588.91
# ----------------------------------------------------------------
